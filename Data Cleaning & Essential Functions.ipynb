# %% [markdown]
# 1. What is data cleaning, and why is it important in data analysis?
#
#     What are the potential consequences of analyzing unclean or messy data?
#
#     Explain the common steps involved in cleaning and organizing data?
#
# ANS- Data cleaning is the process of detecting and correcting errors, inconsistencies, and inaccuracies in raw data to make it reliable and suitable for analysis.
#
# It is Important because high-quality data ensures accurate insights, better business decisions, and reliable machine learning models.
#
# Consequences of Analyzing Messy Data Analyzing unclean data can severely compromise the outcome of your work. Potential consequences include
# Flawed Insights:
# Wasted Resources:
# Lost Trust:
#
# 1. Remove Duplicates & Irrelevant Data:
# 2. Sorting & filtering the data
# 3. Vaidate the data
# 4. Handle Missing Data

# %% [markdown]
# 2. How would you sort the following dataset first by "Department" (A-Z) and then by "Salary" (Largest to
# Smallest)? Write a step-by-step approach.
#
# ![image.png](data:image/png;base64,...)
#
# ANS- FIRST SORT (A TO Z) ENTIRE DATA THEN APPLY FILTER ON SALARY COLUMN (LARGEST TO SMALLEST).

# %% [markdown]
# 3. Explain the use of text functions such as TRIM , LEFT, RIGHT, MID, and
#    CONCAT in data cleaning.
#
#   ANS-  TRIM= Removes all leading, trailing, and extra spaces, leaving only
#         single spaces between words.
#
#        LEFT= Extracts a specified number of characters from the beginning (left
#              side) of a text string.
#        RIGHT= Extracts a specified number of characters from the end (right
#               side) of a text string.
#        MID= Extracts a specific segment starting exactly at the start_num
#             position for a defined length.
#
#        CONCAT= Joins multiple independent strings, cell references, or
#                characters into one single text block.

# %% [markdown]
# 4. What is the role of date functions like TODAY in managing datasets?
#
# ANS- ITS GIVE REAL TIME DATE.

# %% [markdown]
# 5. Apply Data Validation to restrict Quantity values to only whole numbers between 1 and 10.
#
#     Configure an input message that appears when a user selects a cell in the "Quantity" column explaining:
#
#     "Please enter a whole number between 1 and 10."
#     Set up an error alert message that triggers if the user enters a number less than 1 or greater than 10,
#     showing:
#
#     "Invalid input! The quantity must be a whole number between 1 and 10."
#     Write a step-by-step approach for this question?
#
# ANS- SELECT ENTIRE QUANTITY COLUMN THEN APPLY DATA VALIDATION OPITION, UNDER
#      DATA VALIDATION GO TO SETTING THEN ALLOW WHOLE NUMBER THEN SELECT BETWEEN THEN MIN 1 TO MAX 10.

# %% [markdown]
# 6. Extract the first 5 characters from the string "ExcelTipsAreGreat" using the LEFT function.
#
# ANS- =LEFT(A2,5)=Excel.
#
# Extract the last 4 characters from "DataAnalysis.xlsx" using the RIGHT function.
#
# ANS- =RIGHT(A5,4)=xlsx.
#
# Extract the substring "Tips" from "ExcelTipsAreGreat" using the MID function.
#
# ANS- =MID(A9,6,4)=Tips.
#
# Count the total number of characters in the string "Hello World!" using the LEN function.
#
# ANS- =LEN(A12)=12.
#
# Create a formula to extract the middle 6 characters from "12345-67890-ABCDE".
#
# ANS- =MID(A14,6,6)=![image.png](data:image/png;base64,...)

# %% [markdown]
# 7.
#   a.Use CONCAT to combine "Hello" and "World" with a space in between.
#
#   ANS- =CONCAT(A1, " ",B1)=     ![image.png](data:image/png;base64,...)
#
#   b. Combine "Apple", "Banana", and "Cherry" into a single string separated by commas using TEXTJOIN.
#
#   ans-=TEXTJOIN(" ",TRUE,E10:E12)=![image.png](data:image/png;base64,...)
#
#   c. Use the & operator to create the string "2025: Excel Functions" by combining "2025", ": ", and "Excel
#   Functions".
#
# Ans- = "2025" & ": " & "Excel Functions"
#
# d. Create a comma-separated list from the range A1:A5 using TEXTJOIN
#
# Ans- =TEXTJOIN(",", TRUE, A1:A5)
#
# e. Combine first names in column A with last names in column B to create full names in column C.
# Ans- =CONCATENATE(A,B)

# %% [markdown]
# 8. Understanding TODAY() and NOW()
#
#     a. What is the difference between TODAY() and NOW() in Excel? Provide an example of when you would use each function.
#
# Ans- TODAY() returns only the current date, and NOW() returns both the
#     current date and the current time.
#         example =toady ![image.png](data:image/png;base64,...), =now![image.png](data:image/png;base64,...)
#
# b. If cell A1 contains the date 2025-06-10, write a formula using TODAY() to determine how many days are left until that date
#
# Ans- 377 days.
#
# c.  Write an Excel formula using NOW() to display the current date and time in the format MM/DD/YYYY HH:MM AM/PM. ́
#
# ans- =TEXT(NOW(), "mm/dd/yyyy hh:mm AM/PM") ![image.png](data:image/png;base64,...)
#
# d.  If a cell contains =TODAY(), what will happen when the worksheet is reopened the next day? Explain
#
# Ans- When you reopen the worksheet the next day, the cell containing =TODAY() will automatically update to display tomorrow's date.
#
# e. You want to store a static date (today’s date) in a cell without it changing every day. What keyboard shortcut should you use?
#
# Ans-Ctrl + ;
